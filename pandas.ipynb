# %%
try:
    file = open('info.csv','x')
    file.close()
except:
    print("The file is already there!")
# Out:
# The file is already there!

# %%
import pandas as pd
df = pd.read_csv('info.csv')
df
# Out:
#    sn   name  age        add       phone
# 0   1    Ram   34  Kathmandu  9808667876
# 1   2  Shyam   45  Bhaktapur  9808778723
# 2   3   Hari   22   Lalitpur  9808334897
# 3   4   Siva   18      Jhapa  9808667654
# 4   5  Nabin   34  Kathmandu    98667654
# 5   6   Sita   55    Chitwan  9878778765

# %%
df = pd.read_csv('info.csv',nrows = 4,index_col = 'sn')
df
# Out:
#      name  age        add       phone
# sn
# 1     Ram   34  Kathmandu  9808667876
# 2   Shyam   45  Bhaktapur  9808778723
# 3    Hari   22   Lalitpur  9808334897
# 4    Siva   18      Jhapa  9808667654

# %%
df = pd.read_csv('info.csv',index_col = 'sn')
# df.head(4)
df.tail(3)
# Out:
#      name  age        add       phone
# sn
# 4    Siva   18      Jhapa  9808667654
# 5   Nabin   34  Kathmandu    98667654
# 6    Sita   55    Chitwan  9878778765

# %%
df = pd.read_csv('info.csv',index_col = 'sn',usecols = ['sn','name','phone'])
df
# Out:
#      name       phone
# sn
# 1     Ram  9808667876
# 2   Shyam  9808778723
# 3    Hari  9808334897
# 4    Siva  9808667654
# 5   Nabin    98667654
# 6    Sita  9878778765

# %%
df = pd.read_csv('info.csv',index_col = 'sn')
df[['name','phone']]
# Out:
#      name       phone
# sn
# 1     Ram  9808667876
# 2   Shyam  9808778723
# 3    Hari  9808334897
# 4    Siva  9808667654
# 5   Nabin    98667654
# 6    Sita  9878778765

# %%
#iloc loc
df.iloc[1:4]
# Out:
#      name  age        add       phone
# sn
# 2   Shyam   45  Bhaktapur  9808778723
# 3    Hari   22   Lalitpur  9808334897
# 4    Siva   18      Jhapa  9808667654

# %%
df.loc[2:4]
# Out:
#      name  age        add       phone
# sn
# 2   Shyam   45  Bhaktapur  9808778723
# 3    Hari   22   Lalitpur  9808334897
# 4    Siva   18      Jhapa  9808667654

# %%
df['name']
# Out:
# sn
# 1      Ram
# 2    Shyam
# 3     Hari
# 4     Siva
# 5    Nabin
# 6     Sita
# Name: name, dtype: object

# %%
df[df['name'] == "Ram"]
# Out:
#    name  age        add       phone
# sn
# 1   Ram   34  Kathmandu  9808667876

# %%
df[df['age'] >= 25]
# Out:
#      name  age        add       phone
# sn
# 1     Ram   34  Kathmandu  9808667876
# 2   Shyam   45  Bhaktapur  9808778723
# 5   Nabin   34  Kathmandu    98667654
# 6    Sita   55    Chitwan  9878778765

# %%
df[(df['age'] >= 25) & (df['add']=='Kathmandu')]
# Out:
#      name  age        add       phone
# sn
# 1     Ram   34  Kathmandu  9808667876
# 5   Nabin   34  Kathmandu    98667654

# %%
df[(df['age'] >= 25) | (df['add']=='Kathmandu')]
# Out:
#      name  age        add       phone
# sn
# 1     Ram   34  Kathmandu  9808667876
# 2   Shyam   45  Bhaktapur  9808778723
# 5   Nabin   34  Kathmandu    98667654
# 6    Sita   55    Chitwan  9878778765

# %%
info = {'Name':["Ram","Shyam","Hari"],
       'Age':[34,56,32],
       'Address':["Kathmandu","Bhaktapur","Lalitpur"]}
df = pd.DataFrame(info)
df
# Out:
#     Name  Age    Address
# 0    Ram   34  Kathmandu
# 1  Shyam   56  Bhaktapur
# 2   Hari   32   Lalitpur

# %%
df = pd.read_csv('info.csv',index_col = 'sn')

df1 = df[(df['age'] >= 25) | (df['add']=='Kathmandu')]
df1.to_csv('info1.csv')
